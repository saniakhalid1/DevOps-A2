# %%
import requests
from bs4 import BeautifulSoup

# %%
def scrape_web_page(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            text = soup.get_text()
            print(text)
        else:
            print(f"Failed to retrieve the web page. Status code: {response.status_code}")
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")

# %%
url = input("Enter the URL of the web page you want to scrape: ")
scrape_web_page(url)
a=5
b=3
print(a+b)
# Out:
# Enter the URL of the web page you want to scrape: https://www.fpsc.gov.pk/
# ﻿
#
#
#
#
#
#
# Federal Public Service Commission
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Federal Public Service Commission
#
#
#
#
# Search form
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Home
#
#
#
#
#     General Recruitment
#
#
#
#
#     Competitive Examination (CSS)
#
#
#
#
#     Publications
#
#
#
#
#     Downloads
#
#
#
#
#
#
#
#
#
#
#     Forms
#
#
#
#
#     General Instructions
#
#
#
#
#
#
#
#
#
#
#
#     About Us
#
#
#
#
#
#
#
#
#
#
#     Budgetary Details
#
#
#
#
#     FPSC Commission
#
#
#
#
#     FPSC Officers
#
#
#
#
#     About FPSC
#
#
#
#
#     Policies
#
#
#
#
#     Departments
#
#
#
#
#
#
#
#
#
#
#     Legal Wing
#
#
#
#
#     Psychological Wing
#
#
#
#
#     Information Technology Wing
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     Contact Us
#
#
#
#
#
#
#
#
#
#
#     FPSC Offices
#
#
#
#
#     Pension Cell
#
#
#
#
#     Suggestions For Improvements
#
#
#
#
#     Public Information Officer
#
#
#
#
#
#
#
#
#
#
#
#     Apply Online
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Important Updates
#
#
#
#
#
#  Psychological Assessment of Various General Recruitment Cases
#  Conduct of Written (Descriptive) Tests of BS-20 Posts
#  CE-2023 Viva Voce
#  Psychological Assessment Schedule for Various Posts of General Recruitment
#  CE-2023 Psychological Assessment Schedule
#  Psychological Assessment of Various General Recruitment Cases
#  Conduct of Written (Descriptive) Tests of BS-20 Posts
#  CE-2023 Viva Voce
#  Psychological Assessment Schedule for Various Posts of General Recruitment
#  CE-2023 Psychological Assessment Schedule
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Results
# GR Notices
# Jobs
# Representations
# Guidelines
# Syllabi
# CSS Notices
# Interviews
# Admission Certificates
#
#
#
# GR Shortlisting for InterviewGR RecommendationsGeneral Recruitment MarksGR Documents RequiredGR Written Descriptive Tests                        General Recruitment Merit List
#
#
#
#
#
#
#
# GR Biodata FormEdit Application (Current Advertisement)
#
#
#
#
#
#
#
#
#  No Job openings yet
#
#
#
#
#
#
# CSS Marks Recounting Request
#
#
#
#
#
#
# Applying Online for GR
#
#
#
#
#
#
# Syllabi for General Recruitment
#
#
#
#
#
#
# Written CSS Competitive Examination-2023
#
#
#
#
#
#
#
# Interview ProgramsInterview Programs Candidates Lists
#
#
#
#
#
#
# General Recruitment Test Phase 3/2023
#
#
#
#
#
#
#
#
#
#
#           GR Notices
#
#
#
# GR Biodata FormEdit Application (Current Advertisement)
#
#
#
#
#           Results
#
#
# GR Shortlisting for InterviewGR RecommendationsGeneral Recruitment MarksGR Documents RequiredGR Written Descriptive Tests                        General Recruitment Merit List
#
#
#
#           Jobs
#
#
#
#  No Job openings yet
#
#
#
#           Admission Certificates
#
#
# General Recruitment Test Phase 3/2023
#
#
#
#
#           Representations
#
#
# CSS Marks Recounting Request
#
#
#
#           Guidelines
#
#
# Applying Online for GR
#
#
#
#           Syllabi
#
#
# Syllabi for General Recruitment
#
#
#
#           CSS Notices
#
#
# Written CSS Competitive Examination-2023
#
#
#
#
#           Interviews
#
#
# Interview ProgramsInterview Programs Candidates Lists
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Chairman's Message
#
#
#
# The Federal Public Service Commission plays an important role in ensuring merit based recruitment of enterprising candidates to the civil/federal Services. In doing so, we have tried to catalyze the development of the country and the progress of the nation.
# Over the years, demands on the resources of the Commission have increased manifold. To meet these demands and to keep pace with the dynamic environment, we have focused on optimal utilization of technology, introduction of new means of testing and increasing accessibility of the Commission’s functions without compromising on quality and timeliness.
#
# Read More...
#
#
#
#
#
#
#
#
#
#
# FPSC Commission
#
#
#
#  Chairman
#
#  Vacant
#  Members
#
#  Mr. Fazal Abbas Maken
#
#  Mr. Muhammad Tahir
#
#  Mr. Khizar Hayat Khan
#
#  Mr. Akbar Hussain Durrani (TI)
#
#  Dr. Tanveer Ahmed Qureshi
#
#  Ms. Yasmeen Masood
#
#  Mr. Zaheer Pervaiz Khan
#
#  Justice (R) Mushtaq Ahmed
#
#  Mr. Shoaib Dastgir
#
#  Maj. Gen.(R) Naveed Ahmed HI(M)
#
#
#
#
#
#
#
#
#
# Updates/ Web Notices/ Press Releases
#
#
#
#
#
# Psychological Assessment of Various General Recruitment Cases
# Conduct of Written (Descriptive) Tests of BS-20 Posts
# CE-2023 Viva Voce
# Psychological Assessment Schedule for Various Posts of General Recruitment
# CE-2023 Psychological Assessment Schedule
# Pakistan Citizen Portal
# Observance & Implementation of 2% Disability Quota
# Psychological Assessment of Various General Recruitment Cases
# Conduct of Written (Descriptive) Tests of BS-20 Posts
# CE-2023 Viva Voce
# Psychological Assessment Schedule for Various Posts of General Recruitment
# CE-2023 Psychological Assessment Schedule
# Pakistan Citizen Portal
# Observance & Implementation of 2% Disability Quota
#
#
#
#
#     View All >
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Gallery
# External Links
# FAQ's
# Important Contacts
# Tenders
# Official Twitter
#
#
#
#
#
#
#
#
#
#
#
#
#
# Public Service Commissions
#
# Punjab Public Service Commission
# Khyber Pakhtunkhwa Public Service Commission
# Sind Public Service Commission
# Balochistan Public Service Commission
# Azad Jammu & Kashmir Public Service Commission
#
#
#
#
#
#
#
# Contact Us
#
# UAN   : 051-111-000-248
# PABX  : 051-9205075
# FAX     : 051-9203410
# Email    : fpsc@fpsc.gov.pk
# Address : FPSC HQs, Aga Khan Road, Sector F-5/1, Islamabad
#
#
#
#
#
#
#
# Find Us
#
#
#
#
#
#
#
#
#
#
#                  IT WING, FPSC - 2018 (Disclaimer: For all references/ purposes, English version of the website will be considered as official) | Terms | Privacy | SiteMap
